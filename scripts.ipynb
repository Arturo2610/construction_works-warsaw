# %%
import requests
import pandas as pd

# %%
HEADERS = {'Cache-Control' : 'no-cache'}
API_KEY = 'e12d532a-cc5a-4f38-accb-b7ab9edb9e07'
URL = f'''https://api.um.warszawa.pl/api/action/get_companies/?resource_id=2aa01577-9f24-4b8e-83f5-d3d15f6d094b&apikey={API_KEY}'''

# %%
resp = requests.post(URL, HEADERS)
data = resp.json()

# %%
data
# Out:
# {'result': {'IsError': 'false',
#   'ItemsCount': '0',
#   'Items': {'ComboItem': [{'Value': 'City Level Sp. z o.o.', 'Code': '182327'},
#     {'Value': 'ACG 22 Sp. z o.o.', 'Code': '182576'},
#     {'Value': 'IKEBANA Sp. z o.o.', 'Code': '183071'},
#     {'Value': '1 Vision Spółka z ograniczoną odpowiedzialnością SP. K.',
#      'Code': '182606'},
#     {'Value': '1N', 'Code': '181673'},
#     {'Value': '2 X MM Sp z o.o.', 'Code': '182867'},
#     {'Value': '2 X mm Sp. z o.o.', 'Code': '183581'},
#     {'Value': '247 x RADIOACTIVE Sp. z o.o.', 'Code': '182602'},
#     {'Value': '2MREST sp. z o.o.', 'Code': '182902'},
#     {'Value': '3 VEG Sp z o.o.', 'Code': '183504'},
#     {'Value': '3 S S.A.', 'Code': '183051'},
#     {'Value': '4Corners Sp z o.o.', 'Code': '183623'},
#     {'Value': '4 Temat Sp. z o.o. Sp.k.', 'Code': '182991'},
#     {'Value': '5th Inwestycje 8 Sp. z o.o.', 'Code': '183700'},
#     {'Value': '6B47 Poland Sp.z o.o. sp. k.', 'Code': '183691'},
# ...

# %%
pd.DataFrame(data['result'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.DataFrame(data['Value', "Code"])
#
# KeyError: ('Value', 'Code')
